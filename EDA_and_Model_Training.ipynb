# %% [markdown]
# # 🔍 Customer Churn — EDA & Model Training Notebook
#
# This notebook mirrors the production pipeline in `src/` but in an exploratory, step-by-step format.
# Use this for analysis, iteration, and stakeholder demos.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

from src.data_preprocessing import generate_sample_dataset, load_data, get_train_test_split
from src.model_training import train_all_models, get_feature_importance
from utils.helper_functions import *

print('Libraries loaded ✅')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys, os
#       2 sys.path.insert(0, os.path.abspath('..'))
# ----> 4 import pandas as pd
#       5 import numpy as np
#       6 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ## 1. Load Data

# %%
# Generate or load dataset
DATA_PATH = '../data/dataset.csv'
if not os.path.exists(DATA_PATH):
    generate_sample_dataset(DATA_PATH)

df = load_data(DATA_PATH)
print(f'Shape: {df.shape}')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 if not os.path.exists(DATA_PATH):
#       4     generate_sample_dataset(DATA_PATH)
# ----> 6 df = load_data(DATA_PATH)
#       7 print(f'Shape: {df.shape}')
#       8 df.head()
#
# NameError: name 'load_data' is not defined

# %%
# Basic info
print(df.info())
print('\nNull values:')
print(df.isnull().sum())

# %% [markdown]
# ## 2. Exploratory Data Analysis

# %%
# Churn distribution
fig = plot_churn_distribution(df)
fig.show()

# %%
# Tenure vs churn
fig = plot_tenure_vs_churn(df)
fig.show()

# %%
# Monthly charges
fig = plot_monthly_charges(df)
fig.show()

# %%
# Contract type
fig = plot_contract_vs_churn(df)
fig.show()

# %%
# Correlation heatmap
fig = plot_correlation_heatmap(df)
fig.show()

# %% [markdown]
# ## 3. Preprocessing & Feature Engineering

# %%
X_train, X_test, y_train, y_test, scaler, label_encoders, feat_names = get_train_test_split(df)
print(f'Train: {X_train.shape} | Test: {X_test.shape}')
print(f'Churn rate (train): {y_train.mean()*100:.1f}%')

# %% [markdown]
# ## 4. Model Training & Evaluation

# %%
best_model, best_name, results = train_all_models(X_train, X_test, y_train, y_test)
print(f'Best model: {best_name}')

# %%
for name, res in results.items():
    print(f'\n{name}')
    print(res['classification_report'])

# %% [markdown]
# ## 5. Feature Importance

# %%
fi = get_feature_importance(best_model, feat_names)
fig = plot_feature_importance(fi)
fig.show()
